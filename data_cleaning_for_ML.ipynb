# %%
import pandas as pd
import glob
import os

input_folder = "/Users/sehriban/Desktop/Row_Data_Mouse/DE_results/Groups/normal_cell/*csv"
fdr_threshold = 0.05
top_n_genes = 10000

all_expr = []

for file in glob.glob(os.path.join(input_folder)):
    print(f"📂 Processing file: {os.path.basename(file)}")
    
    df = pd.read_csv(file)
    df.columns = df.columns.str.strip()

    if "gene_name" not in df.columns or "FDR" not in df.columns:
        print(f"❌ Skipping {os.path.basename(file)}: missing gene_name or FDR")
        continue

    sig = df[df["FDR"] < fdr_threshold]
    print(f"🔍 {len(sig)} genes passed FDR < {fdr_threshold}")

    if sig.empty:
        print(f"⚠️ No significant genes in {os.path.basename(file)} — skipping")
        continue

    if top_n_genes:
        sig = sig.sort_values("FDR").head(top_n_genes)

    sig = sig.drop_duplicates(subset="gene_name")

    sample_cols = [c for c in sig.columns if c.startswith("SRR")]
    if not sample_cols:
        print(f"⚠️ Skipping {os.path.basename(file)}: no SRR columns found")
        continue

    mat = sig[["gene_name"] + sample_cols]
    mat = mat.set_index("gene_name").transpose()
    mat = mat.reset_index().rename(columns={"index": "sample_id"})

    # Label extraction: expects .0 or .1 at end of sample_id
    mat["label"] = mat["sample_id"].str.extract(r"\.(0|1)$")[0]

    if mat["label"].isnull().any():
        print(f"⚠️ Some labels could not be parsed in {os.path.basename(file)}")

    all_expr.append(mat)

# Final check
if all_expr:
    combined = pd.concat(all_expr, ignore_index=True)
    combined.to_csv("/Users/sehriban/Desktop/Row_Data_Mouse/DE_results/Groups/normal_cell/ML_ready_expression_matrix_normal_cell.csv", index=False)
    print("✅ Saved ML_ready_expression_matrix_mormal_cell.csv")
else:
    print("❌ No data to combine — check logs above.")
# Out:
# 📂 Processing file: data15_DE_results.csv
# 🔍 2082 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data15_DE_results.csv
# 📂 Processing file: data71_DE_results.csv
# 🔍 264 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data71_DE_results.csv
# 📂 Processing file: data64_DE_results.csv
# 🔍 11424 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data64_DE_results.csv
# 📂 Processing file: data79_DE_results.csv
# 🔍 8164 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data79_DE_results.csv
# 📂 Processing file: data89_DE_results.csv
# 🔍 3242 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data89_DE_results.csv
# 📂 Processing file: data63_DE_results.csv
# 🔍 404 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data63_DE_results.csv
# 📂 Processing file: data62_DE_results.csv
# 🔍 12314 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data62_DE_results.csv
# 📂 Processing file: data65_DE_results.csv
# 🔍 12417 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data65_DE_results.csv
# 📂 Processing file: data85_DE_results.csv
# 🔍 154 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data85_DE_results.csv
# 📂 Processing file: data67_DE_results.csv
# 🔍 12922 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data67_DE_results.csv
# 📂 Processing file: data82_DE_results.csv
# 🔍 1062 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data82_DE_results.csv
# 📂 Processing file: data19_DE_results.csv
# 🔍 12521 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data19_DE_results.csv
# 📂 Processing file: data68_DE_results.csv
# 🔍 1863 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data68_DE_results.csv
# 📂 Processing file: data60_DE_results.csv
# 🔍 14817 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data60_DE_results.csv
# 📂 Processing file: data11_DE_results.csv
# 🔍 1499 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data11_DE_results.csv
# 📂 Processing file: data61_DE_results.csv
# 🔍 2224 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data61_DE_results.csv
# 📂 Processing file: data83_DE_results.csv
# 🔍 7246 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data83_DE_results.csv
# 📂 Processing file: data69_DE_results.csv
# 🔍 1006 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data69_DE_results.csv
# 📂 Processing file: data73_DE_results.csv
# 🔍 3562 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data73_DE_results.csv
# 📂 Processing file: data66_DE_results.csv
# 🔍 11569 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data66_DE_results.csv
# 📂 Processing file: data84_DE_results.csv
# 🔍 2122 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data84_DE_results.csv
# 📂 Processing file: data91_DE_results.csv
# 🔍 5868 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data91_DE_results.csv
# 📂 Processing file: data52_DE_results.csv
# 🔍 13300 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data52_DE_results.csv
# 📂 Processing file: data23_DE_results.csv
# 🔍 5174 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data23_DE_results.csv
# 📂 Processing file: data55_DE_results.csv
# 🔍 8357 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data55_DE_results.csv
# 📂 Processing file: data4_DE_results.csv
# 🔍 6911 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data4_DE_results.csv
# 📂 Processing file: data39_DE_results.csv
# 🔍 8017 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data39_DE_results.csv
# 📂 Processing file: data48_DE_results.csv
# 🔍 8349 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data48_DE_results.csv
# 📂 Processing file: data54_DE_results.csv
# 🔍 474 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data54_DE_results.csv
# 📂 Processing file: data53_DE_results.csv
# 🔍 7488 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data53_DE_results.csv
# 📂 Processing file: data37_DE_results.csv
# 🔍 3405 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data37_DE_results.csv
# 📂 Processing file: data59_DE_results.csv
# 🔍 4310 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data59_DE_results.csv
# 📂 Processing file: data35_DE_results.csv
# 🔍 7749 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data35_DE_results.csv
# 📂 Processing file: data51_DE_results.csv
# 🔍 13946 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data51_DE_results.csv
# 📂 Processing file: data56_DE_results.csv
# 🔍 13863 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data56_DE_results.csv
# 📂 Processing file: data33_DE_results.csv
# 🔍 1467 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data33_DE_results.csv
# 📂 Processing file: data57_DE_results.csv
# 🔍 15105 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data57_DE_results.csv
# 📂 Processing file: data21_DE_results.csv
# 🔍 303 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data21_DE_results.csv
# 📂 Processing file: data1_DE_results.csv
# 🔍 2448 genes passed FDR < 0.05
# ⚠️ Some labels could not be parsed in data1_DE_results.csv
# ✅ Saved ML_ready_expression_matrix_mormal_cell.csv

# %%
# 3. Train ML Models in Python
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# 1) Load data
df = pd.read_csv("ML_ready_expression_matrix.csv")
X = df.drop(columns=["sample_id", "label"])
y = df["label"]

print("Class counts:")
print(y.value_counts())

print(X.shape)
print(len(y))


from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, stratify=y, random_state=40
)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
print(y_train.value_counts())
print(y_test.value_counts())



# 3) Common scaler
scaler = StandardScaler()

# 4) Pipelines
pipe_knn = Pipeline([
    ("scaler", scaler),
    ("knn", KNeighborsClassifier())
])
pipe_rf  = Pipeline([
    ("scaler", scaler),
    ("rf", RandomForestClassifier(random_state=44))
])

# 5) Hyperparameter grids
param_grid_knn = {
    "knn__n_neighbors": [3, 5, 7, 9],
    "knn__weights": ["uniform", "distance"],
    "knn__p": [1, 2]  # 1 = Manhattan, 2 = Euclidean
}

param_grid_rf = {
    "rf__n_estimators": [100, 300, 500],
    "rf__max_depth": [None, 10, 20, 30],
    "rf__min_samples_split": [2, 5, 10],
    "rf__min_samples_leaf": [1, 2, 4]
}

# 6) Grid searches (5-fold CV, optimizing accuracy)
grid_knn = GridSearchCV(
    pipe_knn,
    param_grid_knn,
    cv=5,
    n_jobs=-1,
    scoring="accuracy",
    verbose=1
)
grid_rf = GridSearchCV(
    pipe_rf,
    param_grid_rf,
    cv=5,
    n_jobs=-1,
    scoring="accuracy",
    verbose=1
)

# 7) Fit and evaluate KNN
print("=== Tuning KNN ===")
grid_knn.fit(X_train, y_train)
print("Best KNN params:", grid_knn.best_params_)
print(f"Best CV accuracy: {grid_knn.best_score_:.3f}\n")

y_pred_knn = grid_knn.predict(X_test)
print("KNN Classification Report on Test Set:")
print(classification_report(y_test, y_pred_knn))

# 8) Fit and evaluate Random Forest
print("\n=== Tuning Random Forest ===")
grid_rf.fit(X_train, y_train)
print("Best RF params:", grid_rf.best_params_)
print(f"Best CV accuracy: {grid_rf.best_score_:.3f}\n")

y_pred_rf = grid_rf.predict(X_test)
print("Random Forest Classification Report on Test Set:")
print(classification_report(y_test, y_pred_rf))
# Out:
# Class counts:
# Epi    86
# Mes    86
# Name: label, dtype: int64
# (182, 11288)
# 182
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/41/pxzfcbm9535351vmbbnmzj740000gn/T/ipykernel_16485/1904222139.py in <module>
#      23 from sklearn.model_selection import train_test_split
#      24
# ---> 25 X_train, X_test, y_train, y_test = train_test_split(
#      26     X, y, test_size=0.5, stratify=y, random_state=40
#      27 )
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2439         cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2440
# -> 2441         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2442
#    2443     return list(
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#    2020         to an integer.
#    2021         """
# -> 2022         y = check_array(y, ensure_2d=False, dtype=None)
#    2023         return super().split(X, y, groups)
#    2024
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     120     elif X.dtype == np.dtype("object") and not allow_nan:
#     121         if _object_dtype_isnan(X).any():
# --> 122             raise ValueError("Input contains NaN")
#     123
#     124
#
# ValueError: Input contains NaN

# %%
np.random.seed(42)
np.random.shuffle(X)
np.random.seed(42)
np.random.shuffle(Y)
print(np.unique(Y))

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, stratify=Y, random_state=2)
